# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as np

# %%
np.__version__
# Out:
# '1.5.2'

# %%
a1=np.Series(['one',2,3,4,5],index=[0,1,2,3,4])

# %%
VAC_Attendence=np.Series([123,345,567],index=[0,1,2,])

# %%
print(VAC_Attendence)
# Out:
# 0    123
# 1    345
# 2    567
# dtype: int64

# %%
season={"rainy":{1:'nov',2:'dec',3:'jan',4:'feb'},"summer":{1:'mar',2:'aprl',3:'may',4:'jun'}}

# %%
d=np.DataFrame(season,columns=["rainy","summer"])

# %%
d
# Out:
#   rainy summer
# 1   nov    mar
# 2   dec   aprl
# 3   jan    may
# 4   feb    jun

# %%
import numpy as np

# %%
a=pd.DataFrame(np.random.randint(0,300,size=(20,5)),columns=list(('abcde')))

# %%
print(a)
# Out:
#       a    b    c    d    e
# 0   125   72  154   53   77
# 1   283  205   53  166  185
# 2   269  226  273  163  115
# 3   134  134  198  215  163
# 4   110  286  227   25  144
# 5   269  107  298  197  284
# 6   214  224  175  123  155
# 7    70   73  258    4  197
# 8    15  103   16  267  128
# 9    28  292   79  110   21
# 10  202  186  196  150   63
# 11  291  103  229   81   66
# 12  216   72  206  162  192
# 13   25   39  296  149  281
# 14   62  257   65   30   94
# 15   52  160  236  258   62
# 16  165  277  208  178   11
# 17   65  109  248  187  141
# 18  167   61   19  279   85
# 19   17  240   52   91  219

# %%
a.to_csv('C:/Users/ADMIN/Desktop/samarul.csv')

# %%
a
# Out:
#       a    b    c    d    e
# 0   125   72  154   53   77
# 1   283  205   53  166  185
# 2   269  226  273  163  115
# 3   134  134  198  215  163
# 4   110  286  227   25  144
# 5   269  107  298  197  284
# 6   214  224  175  123  155
# 7    70   73  258    4  197
# 8    15  103   16  267  128
# 9    28  292   79  110   21
# 10  202  186  196  150   63
# 11  291  103  229   81   66
# 12  216   72  206  162  192
# 13   25   39  296  149  281
# 14   62  257   65   30   94
# 15   52  160  236  258   62
# 16  165  277  208  178   11
# 17   65  109  248  187  141
# 18  167   61   19  279   85
# 19   17  240   52   91  219

# %%
a.drop("a",axis=1)
# Out:
#       b    c    d    e
# 0    72  154   53   77
# 1   205   53  166  185
# 2   226  273  163  115
# 3   134  198  215  163
# 4   286  227   25  144
# 5   107  298  197  284
# 6   224  175  123  155
# 7    73  258    4  197
# 8   103   16  267  128
# 9   292   79  110   21
# 10  186  196  150   63
# 11  103  229   81   66
# 12   72  206  162  192
# 13   39  296  149  281
# 14  257   65   30   94
# 15  160  236  258   62
# 16  277  208  178   11
# 17  109  248  187  141
# 18   61   19  279   85
# 19  240   52   91  219

# %%
a.drop("b",axis=1)
# Out:
#       a    c    d    e
# 0   125  154   53   77
# 1   283   53  166  185
# 2   269  273  163  115
# 3   134  198  215  163
# 4   110  227   25  144
# 5   269  298  197  284
# 6   214  175  123  155
# 7    70  258    4  197
# 8    15   16  267  128
# 9    28   79  110   21
# 10  202  196  150   63
# 11  291  229   81   66
# 12  216  206  162  192
# 13   25  296  149  281
# 14   62   65   30   94
# 15   52  236  258   62
# 16  165  208  178   11
# 17   65  248  187  141
# 18  167   19  279   85
# 19   17   52   91  219

# %%
d.shape
# Out:
# (4, 2)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 1 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rainy   4 non-null      object
#  1   summer  4 non-null      object
# dtypes: object(2)
# memory usage: 96.0+ bytes
